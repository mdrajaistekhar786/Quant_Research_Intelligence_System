# %%
import streamlit as st

st.title(
    "Quant Research Intelligence System"
)

st.write(
    "Ask questions about quantitative finance research papers."
)
# Out:
# 2026-06-01 14:30:57.116 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:30:58.012
# ...
#   command:
#
#     streamlit run C:\Users\MD RAJA\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-01 14:30:58.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:30:58.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:30:58.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
query = st.text_input(
    "Ask a question"
)
# Out:
# 2026-06-01 14:31:05.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:05.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:05.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:05.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:05.302 Session state does not function when running a script without `streamlit run`
# 2026-06-01 14:31:05.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:05.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if st.button("Search"):

    st.write(
        f"Searching for: {query}"
    )
# Out:
# 2026-06-01 14:31:13.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:13.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:13.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:13.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:13.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if st.button("Search"):

    answer = ask_question(
        query
    )

    st.write(answer)
# Out:
# 2026-06-01 14:31:21.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:21.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:21.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:21.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:31:21.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
sources = [
    "Option pricing under non-Markovian stochastic volatility models",
    "Stochastic Volatility, Jumps, and Rates"
]

for source in sources:
    st.write("•", source)
# Out:
# 2026-06-01 14:32:31.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:31.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.sidebar.title("About")

st.sidebar.write(
    """
    Quant Research Intelligence System

    Features:
    - Hybrid Retrieval
    - Cross Encoder Reranking
    - RAG
    - Research Synthesis
    """
)
# Out:
# 2026-06-01 14:32:40.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:40.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:40.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:40.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.sidebar.subheader("Example Questions")

st.sidebar.write(
    "- What is stochastic volatility?"
)

st.sidebar.write(
    "- Explain option pricing."
)

st.sidebar.write(
    "- Compare volatility models."
)
# Out:
# 2026-06-01 14:32:47.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-01 14:32:47.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
